# %%
#task 3.1

import random

class Tree:
    def __init__(self, data=None):
        self.left_pointer = None
        self.right_pointer = None
        self.data = data

    def insert(self, data):
        if self.data is None:
            self.data = data
        elif data < self.data:     #comparing with the root
            if self.left_pointer is None:     #if the left subtree is empty, can just insert there
                self.left_pointer = Tree(value)
            else:     #left subtree not empty
                (self.left_pointer).insert(value)     #call insert function recursively until it finds a suitable spot
        else:     #data > self.data
            if self.right_pointer is None:     #if the right subtree is empty, can just insert there
                self.right_pointer = Tree(value)
            else:     #right subtree not empty
                (self.right_pointer).insert(value)     #call insert function recursively until it finds a suitable spot

    def in_order(self):
        if self.left_pointer is not None:
            self.left_pointer.in_order()
        print(self.data)
        if self.right_pointer is not None:
            self.right_pointer.in_order()

    def post_order(self):
        if self.left_pointer is not None:
            self.left_pointer.post_order()
        if self.right_pointer is not None:
            self.right_pointer.post_order()
        print(self.data)



mytree = Tree()
for i in range(10):
    value = random.randint(0, 999)
    mytree.insert(value)

print("IN ORDER TRAVERSAL")
mytree.in_order()
print("")

print("POST ORDER TRAVERSAL")
mytree.post_order()
# Out:
# IN ORDER TRAVERSAL
# 40
# 111
# 418
# 450
# 727
# 737
# 764
# 775
# 905
# 928
#
# POST ORDER TRAVERSAL
# 111
# 737
# 764
# 905
# 775
# 727
# 450
# 418
# 928
# 40
